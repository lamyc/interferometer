# %%
import numpy as np
from numpy import exp, pi, cos, sqrt, arcsin
import matplotlib.pyplot as plt
# from control import tf
# from matplotlib.widgets import Slider, Button, RadioButtons

# %%
class Fabry:
    class Mirror:
        def __init__(self, r, t):
            self.r = r
            self.t = t

        
        def _freq_offset(self, dw):
            self.coup_matrix = (1j/self.t*np.ones((len(dw),1,1))
                                *np.array([[-1, self.r],
                                           [-self.r, self.r**2 + self.t**2]]))
            
        def _disp_offset(self, phi):
            self.coup_matrix = exp(2j*phi[:, None, None]*np.array([[0, 1],
                                                                   [-1, 0]]))
            self.coup_matrix[:,0,0] = -1
            self.coup_matrix[:,0,1] *= self.r
            self.coup_matrix[:,1,0] *= -self.r
            self.coup_matrix[:,1,1] = self.r**2 + self.t**2
            self.coup_matrix *= 1j/self.t
            
        def _time_sim(self, alpha):
            self._disp_plot(alpha)
            
            
    class Space:
        def __init__(self, L, n):
            self.length = L
            self.refrac_index = n
            self.optical_dist = L*n
        
        def _freq_offset(self, dk):
            self.coup_matrix = exp(np.array([[1j*self.optical_dist, 0],
                                             [0, -1j*self.optical_dist]])
                                   *dk[:, None, None])
            self.coup_matrix[:,0,1] = self.coup_matrix[:,1,0] = 0
            
        def _disp_offset(self, phi):
            self.coup_matrix = np.identity(2)*np.ones((len(phi),1,1))
        
        def _time_sim(self, dk):
            self._freq_plot(dk)
            
        
    def __init__(self, L0, error0, radius, 
                 lamda=1064, r=(0.8, 1), t=(0.2, 0), m=0.1, refrac_index=1):
        '''
        L0: float
            desired length of the Fabry-Perot Cavity
        error0: float
            expected maximun absolute error of the cavity's initial length
        radius: array_like
            radius of curvature of the input mirror and output mirror respectively.
        lamda: float
            carrier wavelength of the laser, in nm.
        r: array_like
            reflection coefficient of the input mirror and output mirror respectively, range:0 to 1.
        t: array_like
            transmission coefficient of the input mirror and output mirror respectively, range:0 to 1.
        m: float
            phase modulation index of the laser.
        refrac_index: float
            refractive index of the space within the cavity between two mirrors, >= 1.
        '''
        r = np.array(r)
        t = np.array(t)
        radius = np.array(radius)
        if np.any(r**2 + t**2 > 1.):
            raise ValueError("The square sum of relection coef"
                             "and transmission coef should not greater than 1.")
        if (L0*1e9)%lamda > 1e-10:
            raise ValueError("Desired length of the fabry-perot cavity"
                             "should be integer multiple of default laser freq.")
        self.mirror_loss = 1 - r**2 + t**2
        self.desire_length = L0
        self.cavity_length = L0 + error0*(np.random.rand() - 0.5)
        self.reflection_coef = r
        self.transmission_coef = t
        self.input_wavelength = lamda*1e-9 # nm
#         self.modulation_index = m
        self.mirror1 = self.Mirror(r[0], t[0])
        self.mirror2 = self.Mirror(r[1], t[1])
        self.space = self.Space(L0, refrac_index)
        self.lightspeed = 3e8
    
    
    def _cal(self, x, E_in, freq_offset=False, disp_offset=False, TS=False):
        r1, r2 = self.reflection_coef
        t1, t2 = self.transmission_coef
        L = self.cavity_length
        c = self.lightspeed
        
        a0 = E_in
        w0 = 2*pi*c/self.input_wavelength
        
        if freq_offset:
            dw = 2*pi*x
            phi = 0
            self.mirror1._freq_offset(dw/c)
            self.mirror2._freq_offset(dw/c)
            self.space._freq_offset(dw/c)
        elif disp_offset:
            dw = 0
            phi = x
            self.mirror1._disp_offset(phi)
            self.mirror2._disp_offset(np.zeros(len(phi)))
            self.space._disp_offset(phi)
        elif TS:
            dw = x[0]
            phi = x[1]
            alpha = phi*(w0 + dw)/w0
            self.mirror1._time_sim(alpha)
            self.mirror2._time_sim(alpha)
            self.space._time_sim(dw/c)

        self.coup_matrix = (self.mirror1.coup_matrix @ self.space.coup_matrix @ self.mirror2.coup_matrix)
                            
        a2 = a0/self.coup_matrix[:,0,0]
        a4 = a0*self.coup_matrix[:,1,0]/self.coup_matrix[:,0,0]
        a1 = 1j/t1*((r1**2 + t1**2)*a0 - r1*exp(2j*phi*(w0 + dw)/w0)*a4)
        self.trans_power = np.abs(a2)**2
        self.reflect_power = np.abs(a4)**2
        self.circ_power = np.abs(a1)**2
#         self.circ_power = (np.abs(a0)**2 \
#                            * t1**2 \
#                            /(1 + r1**2*r2**2 - 2*r1*r2*cos(2*k*L)))

        self.FSR = c/2/self.cavity_length
        self.FWHM = 2*self.FSR/pi*arcsin((1 - r1*r2)/2/sqrt(r1*r2))
        self.finesse = self.FSR/self.FWHM
        
    def freq_offset(self, freq):
        self._cal(freq, 1, freq_offset=True)
        
    def disp_offset(self, delta_x):
        phi = delta_x*2*pi/self.input_wavelength
        self._cal(phi, 1, disp_offset=True)
        
#     def time_sim(self, freq, delta_x, E_in):
#         self._cal(delta_x, 1, TS=True)
    
    def __str__(self):
        return "FSR: {:>12.3e}Hz\nFWHM: {:>11.3e}Hz\nfinesse: {:.9f}".format(fabry.FSR, fabry.FWHM, fabry.finesse)

# %%
if __name__ == '__main__':
    from scipy.signal import find_peaks
    def plot_power(x_axis, x_label):
        names = ["trans_power", "reflect_power", "circ_power"]
        objs = [fabry.trans_power, fabry.reflect_power, fabry.circ_power]
        for i, name in zip(objs, names):
            plt.plot(x_axis, i, label = name)
            plt.xlabel(x_label)
            plt.legend()
        plt.show()
        
    r = np.array([0.9, 0.98])
    t = sqrt(1 - r**2)
    f = np.linspace(-50, 300, 20000) * 1e6
    fabry = Fabry(1.064, 0, 0, r=r, t=t)
    fabry.freq_offset(f)
    plot_power(f/1e3, "freq offset (kHz)")
    print(fabry)
    
    scale = 1e-8
    dx = np.linspace(-50, 300, 20000)*scale
    fabry.disp_offset(dx)
    plot_power(dx/1e-9, "disp offset (nm)")
    peaks_x, _ = find_peaks(fabry.trans_power)
    print("seperation =", dx[peaks_x][1])
# Out:
# FSR:    1.410e+08Hz
# FWHM:   5.642e+06Hz
# finesse: 24.987112440
# seperation = 5.320266013300666e-07
